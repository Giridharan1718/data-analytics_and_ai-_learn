# %%
l=[2,3,4,5]
print(type(l))
print(l)
# Out:
# <class 'list'>
# [2, 3, 4, 5]

# %%
l.append(7)
print(l)
# Out:
# [2, 3, 4, 5, 7]

# %%
j=[5,6,8]
l.extend(j)
print(l)
# Out:
# [2, 3, 4, 5, 7, 5, 6, 8]

# %%
print(len(l))
# Out:
# 8

# %%
l.insert(2, 10)

# %%
print(l)
# Out:
# [2, 3, 10, 4, 5, 7, 5, 6, 8]

# %%
g=5.0
print(type(g))
# Out:
# <class 'float'>

# %%
g=int(g)
print(type(g))
print(g)
# Out:
# <class 'int'>
# 5

# %%
g=str(g)
print(type(g))
print(g)
# Out:
# <class 'str'>
# 5

# %%
import  numpy as np

# %%
print(np.__version__)
# Out:
# 2.3.5

# %%
arr=[1,2,3,4]
print(type(arr))
# Out:
# <class 'list'>

# %%
arr1=arr * 2
print(arr1)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
l=[]
for i in arr:
    l.append(i*3)
print(l)
# Out:
# [3, 6, 9, 12]

# %%
print(arr)
print(type(arr))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
arr=np.array(arr)
print(type(arr))
print(arr)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4]

# %%
print(arr*2)
# Out:
# [2 4 6 8]

# %%
brr=np.array([1,2,3,4])
print(arr+brr)
# Out:
# [2 4 6 8]
